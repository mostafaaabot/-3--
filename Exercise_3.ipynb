# %% [markdown]
# <div dir="rtl">
#     <h2>مقدمه</h2>
#     <font size="4">
#         در این تمرین، شما با یک مسئله رگرسیون روبرو هستید که هدف آن پیش‌بینی یک ویژگی خاص از یک دیتاست است. برای حل این مشکل، شما باید از روش‌های مختلف پیش‌پردازش داده‌ها، انتخاب ویژگی‌ها، و مدل‌سازی استفاده کنید. این تمرین شامل مراحل زیر خواهد بود:
#     </font>
# </div>
#
# <div dir="rtl">
#     <h3>قدم اول: ارزیابی و شناخت دیتاست</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم دوم: پیش‌پردازش داده‌ها</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم سوم: مصورسازی و بررسی داده‌ها و متغیرها</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم چهارم: مهندسی ویژگی / انتخاب ویژگی</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم پنجم: مدل‌سازی اولیه</h3>
# </div>
#
# <div dir="rtl">
#     <h3>قدم ششم: بهینه‌سازی مدل(های) منتخب</h3>
# </div>
# <br>
#
# <div dir="rtl">
#     <h2>توضیح دیتاست</h2>
#     <p>این مجموعه داده شامل اطلاعاتی درباره کیفیت هوا است. ویژگی‌های مختلف در این دیتاست عبارت‌اند از:</p>
# </div>
# <div dir="rtl">
#     <font size=4>
#         <li><strong>0 - تاریخ (DD/MM/YYYY):</strong> تاریخ ثبت داده‌ها</li>
#         <li><strong>1 - زمان (HH.MM.SS):</strong> زمان ثبت داده‌ها</li>
#         <li><strong>2 - غلظت CO (مقدار mg/m³):</strong> غلظت دی‌اکسید کربن به صورت میانگین ساعتی</li>
#         <li><strong>3 - PT08.S1 (سنسور اکسید قلع):</strong> پاسخ سنسور برای شناسایی CO</li>
#         <li><strong>4 - غلظت Non Metanic HydroCarbons (µg/m³):</strong> غلظت کل هیدروکربن‌های غیر متان</li>
#         <li><strong>5 - غلظت بنزن (µg/m³):</strong> غلظت بنزن</li>
#         <li><strong>6 - PT08.S2 (سنسور تیتانیا):</strong> پاسخ سنسور برای شناسایی Non Metanic HydroCarbons</li>
#         <li><strong>7 - غلظت NOx (ppb):</strong> غلظت نیتروژن اکسیدها</li>
#         <li><strong>8 - PT08.S3 (سنسور اکسید تنگستن):</strong> پاسخ سنسور برای شناسایی NOx</li>
#         <li><strong>9 - غلظت NO2 (µg/m³):</strong> غلظت دی‌اکسید نیتروژن</li>
#         <li><strong>10 - PT08.S4 (سنسور اکسید تنگستن):</strong> پاسخ سنسور برای شناسایی NO2</li>
#         <li><strong>11 - PT08.S5 (سنسور اکسید ایندیوم):</strong> پاسخ سنسور برای شناسایی O3</li>
#         <li><strong>12 - دما (درجه سانتی‌گراد):</strong> دمای محیط</li>
#         <li><strong>13 - رطوبت نسبی (%):</strong> میزان رطوبت محیط</li>
#         <li><strong>14 - رطوبت مطلق (AH):</strong> مقدار رطوبت مطلق</li>
#     </font>
# </div>

# %% [markdown]
# <div dir="rtl">
#     <font size=5 color="red"> راهنمای تمرین:</font>
#     <br>
#     <p>
#         <font size=4>
#         این تمرین به گونه‌ای طراحی شده که شما باید کدهای خود را در قالب خاصی که از قبل مشخص شده، بنویسید. به این معنی که ممکن است بخشی از کد برای شما آماده باشد و شما باید فقط ادامه کد را بنویسید بدون اینکه آن قسمت از کد را تغییر دهید. این نوع تمرین برای کمک به شما طراحی شده تا در مراحل بعدی با چالش‌های پیچیده‌تری روبرو شوید که نیاز به مهارت‌های بیشتری دارند.
#         <br>
#         در این تمرین، در هر مرحله شما باید برداشت‌ها و تحلیل‌های خود را بنویسید. مثلاً اگر در کد شما نمودار یا جدولی از داده‌ها یا نتایج مدل‌ها به نمایش در می‌آید، شما باید توضیح دهید که آن‌ها چه معنی و کاربردی دارند. این تحلیل‌ها می‌تواند شامل بررسی تغییرات در داده‌ها، ارزیابی مدل‌ها، یا نتایج بهینه‌سازی‌ها باشد.
#         <br>
#         برای هر بخش، حداقل پنج نکته یا برداشت از نتایج یا داده‌ها باید بنویسید.
#         <br>
#             <li>
#             در قسمت ارزیابی , باید یافته ها و نکاتی که از تحلیل داده متوجه شده و دریافت کرده اید در قالب یک خلاصه گزارش , بنویسید.
#             </li>
#             <li>
#             برای هر نمودار یا جدول، تحلیل کنید که چه روندی را نشان می‌دهند یا آیا نکته خاصی برای بهبود مدل یا داده‌ها از آن‌ها قابل استخراج است.
#             </li>
#             <br>
#         مهم است که توجه داشته باشید شما باید فقط کدهای خود را اضافه کنید و قسمت‌هایی که از پیش نوشته شده‌اند، نباید تغییر کنند. هدف این است که شما بتوانید با استفاده از قالب و راهنمایی‌های داده شده، تمرین را به درستی تکمیل کنید.
#         </font>
#     </p>
# </div>
# <br>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <font size=5 color="red">
#     اهداف تمرین:
#     </font>
#     <font size=4>
#         <li>مقدار MSE باید کمتر از 0.20 باشد</li>
#         <li>مقدار R2 باید بیشتر از 0.85 باشد</li>
#         <li>مدل نهایی نباید Overfit/Underfit شده باشد.</li>
#     </font>
#
# </div>
# <br>
# <br>

# %% [markdown]
# __________________

# %% [markdown]
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم اول: ارزیابی و شناخت دیتاست</strong>
#     </li>
# </font>
# <font size="4">
#     در این قدم، شما باید دیتاست را بررسی کرده و ساختار آن را درک کنید. بررسی کنید که چه متغیرهایی در دیتاست وجود دارند، نوع داده‌ها چیست و آیا داده‌ها گمشده یا نادرست هستند یا خیر. این مرحله به شما کمک می‌کند که به‌طور کامل با داده‌ها آشنا شوید و مشکلات احتمالی را شناسایی کنید.
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#             کتابخانه و ماژول های مورد نیاز برای قدم اول این تمرین را در محیط برنامه نویسی لود کنید:
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO: کتابخانه ها را ایمپورت کنید

import pandas as pd
import numpy as np

# %%
# TODO: دیتافریم را لود کنید

from google.colab import drive
drive.mount ('/content/drive/')

path='/content/drive/MyDrive/Computer Programming/dataset.csv'
df=pd.read_csv(path,sep=";")
df.head()
# Out:
# Mounted at /content/drive/
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# 0  0,7578          NaN          NaN
# 1  0,7255          NaN          NaN
# 2  0,7502          NaN          NaN
# 3  0,7867          NaN          NaN
# 4  0,7888          NaN          NaN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#             دیتافریم را ارزیابی کنید مثلا:
#             </li>
#             1. ابعاد دیتافریم
#             <br>
#             2. نوع دیتاتایپ و تعداد ویژگی های
#             <br>
#             3. داده های تکراری و NaN
#             <br>
#             4. ...
#         </font>
#     </p>
# </div>

# %%
# TODO : بررسی چند ردیف اول دیتافریم
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# 0  0,7578          NaN          NaN
# 1  0,7255          NaN          NaN
# 2  0,7502          NaN          NaN
# 3  0,7867          NaN          NaN
# 4  0,7888          NaN          NaN

# %%
# TODO: بررسی ابعاد دیتافریم
df.shape
# Out:
# (9471, 17)

# %%
# TODO: بررسی اطلاعات کلی دیتافریم
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# dtypes: float64(10), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# ### ارزیابی:
# 1. دارای 9471 رکورد در 17 ستون است و دارای مقادیر خالی = 9357 . مقادیر خالی جایگزین شوند.
# 2. یکسری از داده ها عددی و یکسری غیرعددی است که باید تبدیل شوند
# 3. تعداد تنوع داده ها در خاص بودن بسیار متفاوت است که کار کدگذاری مجدد را سخت می کند.
#
# 4. تفاوت میانگین داده های عددی بالاست که نیاز به نرمال سازی یا استاندارسازی را نشان می دهد. حد کف و سقف داده هم برای برخی موارد بسیار متفاوت است.

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#                 داده های تکراری (Duplicates) و داده های گم شده (Missing Values) را بررسی و ارزیابی کنید.
#                 <strong>سپس مقادیر تکراری را حذف کنید.</strong>
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO: بررسی مقادیر گم شده
df.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
# TODO: بررسی داده های تکراری
df.duplicated().sum()
# Out:
# np.int64(113)

# %%
# حذف داده های تکراری
df.drop_duplicates(inplace=True,keep=False)
df.shape
# Out:
# (9357, 17)

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#                 با کمک کتابخانه <code>missingno</code> مقادیر گم شده را مصورسازی کنید.
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO:  مصور سازی داده های گم شده
#با کمک کتابخانه مقایر ناموجود تصویرسازی شده
import missingno
missingno.bar(df,log=True,figsize=(10,5),color="tab:green",fontsize=12,sort="ascending")
# Out:
# /usr/local/lib/python3.11/dist-packages/missingno/missingno.py:271: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_yticklabels([int(n * len(df)) for n in ax1.get_yticks()], fontsize=fontsize)
# <Axes: >

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#                 تعداد مقادیر یکتا (Unique) در هر ویژگی را بررسی کنید.
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO: بررسی تعداد داده های منحصر بفرد و یکتا در هر ویژگی
df.nunique()
# Out:
# Date              391
# Time               24
# CO(GT)            104
# PT08.S1(CO)      1042
# NMHC(GT)          430
# C6H6(GT)          408
# PT08.S2(NMHC)    1246
# NOx(GT)           926
# PT08.S3(NOx)     1222
# NO2(GT)           284
# PT08.S4(NO2)     1604
# PT08.S5(O3)      1744
# T                 437
# RH                754
# AH               6684
# Unnamed: 15         0
# Unnamed: 16         0
# dtype: int64

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#                 جدول Describe را برای این دیتافریم بررسی کنیدو ارزیابی اولیه خودتان را در مورد این دیتافریم بنویسید.
#                 در ادامه که نمونه از ارزیابی اولیه برای شما نوشته شده است که لازم است با آن توجه داشته باشید
#             </li>
#         </font>
#     </p>
# </div>

# %%
# TODO: بررسی اطلاعات آمار و احتمالاتی دیتاست
df.describe()
# Out:
#        PT08.S1(CO)     NMHC(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)  \
# count  9357.000000  9357.000000    9357.000000  9357.000000   9357.000000
# mean   1048.990061  -159.090093     894.595276   168.616971    794.990168
# std     329.832710   139.789093     342.333252   257.433866    321.993552
# min    -200.000000  -200.000000    -200.000000  -200.000000   -200.000000
# 25%     921.000000  -200.000000     711.000000    50.000000    637.000000
# 50%    1053.000000  -200.000000     895.000000   141.000000    794.000000
# 75%    1221.000000  -200.000000    1105.000000   284.000000    960.000000
# max    2040.000000  1189.000000    2214.000000  1479.000000   2683.000000
#
#            NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  Unnamed: 15  Unnamed: 16
# count  9357.000000   9357.000000  9357.000000          0.0          0.0
# mean     58.148873   1391.479641   975.072032          NaN          NaN
# std     126.940455    467.210125   456.938184          NaN          NaN
# min    -200.000000   -200.000000  -200.000000          NaN          NaN
# 25%      53.000000   1185.000000   700.000000          NaN          NaN
# 50%      96.000000   1446.000000   942.000000          NaN          NaN
# 75%     133.000000   1662.000000  1255.000000          NaN          NaN
# max     340.000000   2775.000000  2523.000000          NaN          NaN

# %% [markdown]
# ### ارزیابی:
# 1.  -200 هستند که احتمالاً نشان‌دهنده داده‌های نامعتبر یا مقادیر گمشده است
# 2. مقادیر انحراف ستون ها بسیار بالاست که حضور عدد منفی 200 در این بین بی تاثیر نیست.
# 3. در خصوص ستون دوم با توجه به کف و سقف عددی، مقادیر چارک ها باز هم منفی 200 شده که نشان از اثر داده نامعتبر است.

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4>
#             <li>
#             با توجه به توضیحات که ما برای شما در ارزیابی جدول آمار احتمالاتی نوشته ایم , تعداد مقادیر نویزی و نامعتبر در هر ویژگی را اندازه  گیری کنید.
#             خروجی مورد انتظار به صورت زیر است اما توجه داشته باشید مقادیری که شما به دست میاورید متفاوت خواهد بود.
#             </li>
#         </font>
#     </p>
# </div>

# %% [markdown]
# ```code
# تعداد مقادیر غیرواقعی (کمتر از0 ) در هر ستون:
# PT08.S1(CO)       100
# NMHC(GT)         33
# PT08.S2(NMHC)     67
# .
# .
# .
# ```

# %%
# TODO: بررسی تعداد مقادیر نامعتبر در ستون‌های عددی

data_numeric=df[df.columns[df.dtypes==np.float64]]
for col in data_numeric.columns:
  negative_sum=data_numeric[data_numeric[col]<0][col].count()
  print(f"{col}: {negative_sum}")
# Out:
# PT08.S1(CO): 366
# NMHC(GT): 8443
# PT08.S2(NMHC): 366
# NOx(GT): 1639
# PT08.S3(NOx): 366
# NO2(GT): 1642
# PT08.S4(NO2): 366
# PT08.S5(O3): 366
# Unnamed: 15: 0
# Unnamed: 16: 0

# %% [markdown]
# <div dir="rtl">
#     <p>
#         <font size=4, color="red">
#             <li>
#                 <strong>
#                     در خصوص عدد <code>-200</code> که به کرات در این دیتافریم دیده می شود تحقیق کنید و نتیجه تحقیق خود را در قسمت پایین بنویسید:
#                 </strong>
#             </li>
#         </font>
#     </p>
# </div>

# %% [markdown]
# ###  نتیحه ارزیابی در خصوص اعداد -200:
# 1. گاهی اوقات این عدد به صورت توافقی نمایانگر داده هایی است که سنسورها آنها را در زمان مشخص ثبت نکرده اند
# 2. گاهی این عدد نشان می دهد که سنسورها دارای خطا در ثبت داده بودند و خطای 200 را ثبت کرده اند.
# 3. گاهی نشان میدهد مقدار عدد خارج از رنج مورد انتظار بوده یا در مرحله پاکسازی داده یا تبدیل داده خطایی رخ داده است.
#
#     4.احتمالا خطای -200 میتواند مشابه به خطای 404 باشد.یعنی نشان دهنده ی نبود اطلاعات یا دارای مشکل بودن ان ها

# %% [markdown]
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم دوم: پیش‌پردازش داده‌ها</strong>
#     </li>
# </font>
# <font size="4">
#     در این مرحله، شما باید داده‌ها را با استفاده از نمودارها و آمار توصیفی تحلیل کنید. بررسی توزیع متغیرها، همبستگی بین ویژگی‌ها و شناسایی داده‌های پرت به درک بهتر الگوهای موجود در دیتاست کمک می‌کند.
# </font>
# </div>
# <br>

# %%
# در ابتدا یک کپی از دیتافریم اصلی میگیریم.
df_copy = df.copy()

import matplotlib.pyplot as plt
import seaborn as sns

#-----------------------------نمایش توزیع ها
plt.figure(figsize=(10,6))
sns.histplot(df_copy,kde=True)
plt.title('Air Quality')
plt.show()
#------------------------------ داده های پرت
plt.figure(figsize=(10,6))
ax=data_numeric.boxplot()
plt.xticks(rotation=45, ha='right')
plt.xlabel('Criteria of Air Quality')
plt.ylabel('Measure')
plt.tight_layout()
plt.show()
#-------------------------------همبستگی بین متغیری
df_copy.corr(numeric_only=True)
mask=np.triu(np.ones_like(df_copy.corr(numeric_only=True)))
dataplot=sns.heatmap(df_copy.corr(numeric_only=True),cmap="YlGnBu",annot=True, mask=mask)
plt.show()

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#             Datatype هارو اصلاح کنید.
#         </li>
#     </font>
#
#
# </div>
# <br>

# %%
def clean_and_convert(df):
#step1-----------------------------------
    df['Date']=pd.to_datetime(df['Date'],format='%d/%m/%Y',errors='coerce')
#step2-----------------------------------
    def timeToHour(value):
      splitted=str(value).split(".")
      return splitted[0]
    df['Hour']=df['Time'].apply(timeToHour).astype('float')
#step3-----------------------------------
    matching_columns = [col for col in df.columns if df[col].astype(str).str.contains(',').any()]

    for col in matching_columns:
        df[col]=df[col].astype(str).str.replace(',','.')
        df[col]=df[col].astype('float')

    return df


    
    pass  # TODO

# اعمال متد روی دیتاست
df_copy = clean_and_convert(df_copy)

# %%
# TODO: مجددا نوع داده هارو بررسی کنید تا از تغییرات مد نظر مطمئن شوید.
df.info()
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9357 entries, 0 to 9356
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# dtypes: float64(10), object(7)
# memory usage: 1.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 9357 entries, 0 to 9356
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   datetime64[ns]
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
#  17  Hour           9357 non-null   float64
# dtypes: datetime64[ns](1), float64(16), object(1)
# memory usage: 1.4+ MB

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#             اگر دیتافریم شامل ستونی است که برای تحلیل و مدل سازی ما مناسب نیست آن را حذف کنید.
#         </li>
#     </font>
# </div>

# %%
# TODO: حذف ستون نامعتبر
df_copy.drop(['Time','NMHC(GT)','Unnamed: 15','Unnamed: 16'], axis='columns', inplace=True)
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9357 entries, 0 to 9356
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   datetime64[ns]
#  1   CO(GT)         9357 non-null   float64
#  2   PT08.S1(CO)    9357 non-null   float64
#  3   C6H6(GT)       9357 non-null   float64
#  4   PT08.S2(NMHC)  9357 non-null   float64
#  5   NOx(GT)        9357 non-null   float64
#  6   PT08.S3(NOx)   9357 non-null   float64
#  7   NO2(GT)        9357 non-null   float64
#  8   PT08.S4(NO2)   9357 non-null   float64
#  9   PT08.S5(O3)    9357 non-null   float64
#  10  T              9357 non-null   float64
#  11  RH             9357 non-null   float64
#  12  AH             9357 non-null   float64
#  13  Hour           9357 non-null   float64
# dtypes: datetime64[ns](1), float64(13)
# memory usage: 1.1 MB

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         حالا که متوجه شدیم دیتافریم ما دارای نویز است
#         بهترین راه حل را برای مواجه با این مشکل پیدا کنید و آن را پیاده سازی کنید
#         <br>
#         منظور اعداد -200 است. در این قسمت شما باید تصیمیم بگیرید بهترین روش برخورد با این مقدار چیه.
#         <br>
#         قبل از انجام هر کاری مطمئن شوید که تحقیقات کامل درمورد دلیل وجود این عداد کرده باشید.
#     </font>
# </div>

# %%
# TODO : مشکل اعداد -200 را برطرف کنید.

#تبدیل مقادیر -200 به سلول های خالی
for col in df_copy.columns:
  df_copy[col]=df_copy[col].replace(-200,np.nan)

df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9357 entries, 0 to 9356
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   datetime64[ns]
#  1   CO(GT)         7674 non-null   float64
#  2   PT08.S1(CO)    8991 non-null   float64
#  3   C6H6(GT)       8991 non-null   float64
#  4   PT08.S2(NMHC)  8991 non-null   float64
#  5   NOx(GT)        7718 non-null   float64
#  6   PT08.S3(NOx)   8991 non-null   float64
#  7   NO2(GT)        7715 non-null   float64
#  8   PT08.S4(NO2)   8991 non-null   float64
#  9   PT08.S5(O3)    8991 non-null   float64
#  10  T              8991 non-null   float64
#  11  RH             8991 non-null   float64
#  12  AH             8991 non-null   float64
#  13  Hour           9357 non-null   float64
# dtypes: datetime64[ns](1), float64(13)
# memory usage: 1.1 MB

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#         نمودار هیت مپ داده های گم شده (Missing Values) را به کمک ماژول Seaborn رسم کنید و ارزیابی خودتان را بنویسید
#         </li>
#         <br>
#         راهنمایی: از نمودار Heatmap استفاده کنید.
#     </font>
# </div>
# <br>

# %%
# TODO: نمودار پراکندگی داده های گمشده را رسم کنید.
ax=plt.axes()
sns.heatmap(df_copy.isna(),cmap="mako",cbar=False,ax=ax)
plt.title('Missing values', fontsize=12)
plt.xlabel('Air Quality Criteria', fontsize=10)
plt.ylabel('Records', fontsize=10)
plt.show()

# %% [markdown]
# ### ارزیابی:
#
# 1. هر چه نقاط پرت شدیدتر شده از رنگ آمیزی یکنواخت دورتر شده است.
# 2. داده های گم شده بین چند ستون زیاد و مشترک هستند که باید حذف شوند.

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#     <li>
#         .حل مشکل داده های گم شده
#         راه حلی برای برخورد با مقادیر گم شده پیدا و آن را پیاده سازی کنید
#     </li>
#     </font>
# </div>

# %%
# TODO : مقادیر گم شده را مدیریت کنیئ
 #حذف مقادیر مشترک بین ستون ها
df_copy = df_copy.drop_duplicates(subset=['PT08.S1(CO)','PT08.S2(NMHC)'], keep=False)

# %%
# TODO : مقادیر گم شده را مدیریت کنیئ
# پر کردن مقادیر یا میانگین داده ها
df_copy = df_copy.fillna(df_copy.mean())

# %%
# TODO : مقادیر گم شده را مدیریت کنیئ
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8693 entries, 0 to 9356
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8693 non-null   datetime64[ns]
#  1   CO(GT)         8693 non-null   float64
#  2   PT08.S1(CO)    8693 non-null   float64
#  3   C6H6(GT)       8693 non-null   float64
#  4   PT08.S2(NMHC)  8693 non-null   float64
#  5   NOx(GT)        8693 non-null   float64
#  6   PT08.S3(NOx)   8693 non-null   float64
#  7   NO2(GT)        8693 non-null   float64
#  8   PT08.S4(NO2)   8693 non-null   float64
#  9   PT08.S5(O3)    8693 non-null   float64
#  10  T              8693 non-null   float64
#  11  RH             8693 non-null   float64
#  12  AH             8693 non-null   float64
#  13  Hour           8693 non-null   float64
# dtypes: datetime64[ns](1), float64(13)
# memory usage: 1018.7 KB

# %% [markdown]
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم سوم: مصورسازی و بررسی متغیرها</strong>
#     </li>
# </font>
# <font size="4">
#                     در این قدم، شما باید با استفاده از ابزارهای مصورسازی مانند نمودارهای پراکندگی (Scatter plots)، هیستوگرام‌ها و نمودارهای جعبه‌ای (Box plots)، روابط بین ویژگی‌ها و هدف را بررسی کنید. این مرحله به شما کمک می‌کند که روابط پنهان میان متغیرها را شناسایی کنید و درک بهتری از داده‌ها پیدا کنید.
#                     شما میتوانید هرگونه مصورسازی که فکر می کنید در این مرحله اطلاعاتی به شما میدهد را انجام دهید. <br>
#                     <font color="red">ولی پیاده سازی پلات های خواسته شده الزامی می باشد.</font>
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#         توزیع (Distribution) تمامی داده های عددی را بررسی کنید و موارد و نکات مهمی که از این توزیع ها دریافت کرده ایید را در قسمت ارزیابی بنویسید.
#     </font>
# </div>
# <br>

# %%
# TODO : توزیع ویژگی های عددی را بررسی کنید
for col in df_copy.drop('Date',axis='columns').columns:
  plt.figure(figsize=(8,4))
  sns.histplot(df_copy[col],kde=True,bins=20)
  plt.title(f'Distribution of {col}')
  plt.show()

# %% [markdown]
# ###  ارزیابی:
# 1. نمودارهای 1 تا 7 دارای  چولگی زیادی به سمت راست می باشند که نشان از آن دارد شاخص های مرکزیت روی هم منطبق نشده اند و نیاز به استانداردسازیست.
# 2. نمودارهای 7 تا 12 تقریبا نرمال متقارن هستند و میانگین، میانه و مد بر روی هم قرار گرفته اند.
# 3. نمودار مربوط به ساعت تقریبا توزیع زنگدیسی ندارد و نرمال نیست. در حقیقت الگوی تکرار شونده ای در آن دیده می شود.

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#             نمودار پراکندگی داده ایی (Scatter Plot) عدد به نسبت داده های ویژگی هدف را بررسی کنید و نکات مهمی را که از این نمودار ها متوجه شده ایید را در قسمت ارزیابی بنویسید.
#         </li>
#         <font color="red">
#         توجه داشته باشید که باید متد زیر را کامل کنید. به توضیحات Docstring تابع توجه کنید.
#         </font>
#     </font>
# </div>
# <br>

# %%
# TODO: نمودار Scatter را برای داده های عددی رسم کنید
def plot_scatter_separately(df, target_variable):

  #step1
  if not target_variable in df.columns:
    print("Target is not available in the detaset")

  #step2
  numeric_df=list(df[df.columns[df.dtypes==np.float64]].columns)
  numeric_df.remove(target_variable)

  #step3
  for col in numeric_df:
    plt.figure(figsize=(10,6))
    plt.scatter(x=df[col],y=df[target_variable],color='blue',alpha=0.5)
    plt.xlabel(col)
    plt.ylabel(target_variable)
    plt.title(f'Plot of {col} and Target')
    plt.show

    
    pass  # TODO

plot_scatter_separately(df_copy, 'CO(GT)')

# %% [markdown]
# ###  ارزیابی:
# 1. توزیع ویژگی های عددی که دارای چولگی بودند نشان از همبستگی مثبت بیشتری با متغیر هدف هستند.
# 2. در پلات پنجم بر خلاف سایر متغیرها ارتباط لگاریتمی و غیرخطی با متغیر هدف مشاهده  شد.
# 3. پلات 9 و 10 و 11 فاقد هر گونه ارتباط با متغیر هدف هستند.
# 4. مقدار متغیر هدف بر اساس افزایش میزان ساعت آلودگی دارای نوسان های سینوسی بوده.

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#                Boxplotیکی از روش های بررسی برای وجود داده های پرت است. البته Boxplot کاربردی های بسیاری دارد مانند بررسی نسبت داده های عددی با داده های دسته ایی.
#         </li>
#     </font>
# </div>
# <br>

# %%
# TODO: نمودار های Boxplot را رسم کنید
#رسم بصورت حدودی است
numeric_df=df_copy[df_copy.columns[df_copy.dtypes==np.float64]]

for col in numeric_df.columns:
    plt.figure(figsize=(10,6))
    numeric_df.boxplot([col])
    plt.xlabel(col)
    plt.tight_layout()
    plt.show

# %% [markdown]
# ###  ارزیابی:
# 1. با توجه به اینکه در نمودار جعبه ای، 55 درصد از نقاط داده در جعبه نمایش داده می شود و خط وسط مقدار میانه است، نقاط خارج از محدوده میان چارکی نمایان گر داده های با فاصله از مقادیر وسط خواهد بود.

# %% [markdown]
# <div dir="rtl">
#     <font size=5>
#     <li>مدیریت مقادیر های پرت (Outliers)</li>
#     </font>
# </div>

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         تا به امروز از روش های مختلفی برای مدیریت داده های پرت مانند IQR و Z-Score استفاده کرده ایم. در این جا میخواهیم از روشی به نام Winsorize برای مدیریت این نوع از داده ها استفاده کنیم. به توضیحات داده شده در Docstring تابع زیر توجه کنید و تابع را کامل کنید.  برای مطالعه درباره ی Winsorization به لینک های زیر مراجعه نمایید.
#     </font>
# </div>
# <br>

# %% [markdown]
# [Winsorized Mean - DataCamp](https://www.datacamp.com/tutorial/winsorized-mean)
#
# [scipy.stats.mstats.winsorize - SciPy Documentation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mstats.winsorize.html)

# %%
from scipy.stats.mstats import winsorize

# TODO: مدیریت داده های پرت
def winsorize_and_handle_missing(df, cols, limits=[0.05, 0.05]):
  #step1
  df_copy=df.copy()

  #step2
  for col in cols:
    df_copy[col]=winsorize(df[col], limits)

  return df_copy

  #متاسفانه به نتیجه دلخواه نرسیدم
    TODO

# %%
# TODO: مدیریت داده های پرت
df_copy=winsorize_and_handle_missing(df_copy, df_copy.drop(['Date','RH','Hour'],axis='columns').columns)
df_copy.columns
# Out:
# Index(['Date', 'CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)',
#        'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH',
#        'AH', 'Hour'],
#       dtype='object')

# %% [markdown]
# <br>
# <div dir="rtl">
# <font size="4">
#     <li>
#     <strong>نمودار Heatmap را برای این دیتافریم رسم کنید </strong>
#     </li>
# </font>
# </div>
# <br>

# %%
# TODO: نمودار هیت مپ را بررسی کنید
ax=plt.axes()
sns.heatmap(df_copy.drop('Date',axis='columns'), cbar=True, ax=ax)
plt.title('Heatmap of the dataframe', fontsize=12)
plt.xlabel('Columns', fontsize=10)
plt.show()

# %% [markdown]
# ###  ارزیابی:
#
# 1. هر ستون طیف رنگ خیلی تفاوت ندارد و این بیان گر حذف داده های پرت بر اساس روش اصلاح داده بر اساس صدک ها می باشد.

# %% [markdown]
# <br>
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم چهارم: مهندسی و انتخاب ویژگی</strong>
#     </li>
# </font>
# <font size=4>
#     در این مرحله، ویژگی‌های مناسب برای مدل‌سازی انتخاب شده و ویژگی‌های غیرضروری حذف یا اصلاح می‌شوند. مهندسی ویژگی شامل ایجاد ویژگی‌های جدید، تبدیل داده‌های دسته‌ای به عددی و ... است. هدف این مرحله بهبود عملکرد مدل با انتخاب ویژگی‌های تأثیرگذار و کاهش پیچیدگی داده‌ها است.
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <font size="4">
#         هدف این بخش، تحلیل همبستگی چندجمله‌ای و انتخاب ویژگی در این مرحله شما باید:
#     </font><br>
#     <font size="5">
#         1. تحلیل همبستگی چندجمله‌ای:
#     </font><br>
#     <font size="4">
#             <li>متدی بنویسید که ویژگی‌هایی که چند همبستگی (Multicollinearity) دارند را پیدا کرده و فقط یکی از آن‌ها را انتخاب کند.</li>
#             <font color="red">نکته : از تحلیل واریانس برای این قسمت نیز استفاده کنید.</font>
#     </font>
#     <br>
#     <br>
#     <font size="5">
#         2. انتخاب ویژگی با Mutual Information:
#     </font><br>
#     <font size="4">
#             <li>ویژگی‌هایی را با کمک روش Mutual Information انتخاب کنید.</li>
#     </font>
#         <br>
#     <font size="5">
#         3.مهندسی ویژگی یا Feature Engineering
#     </font><br>
#     <font size="4">
#             <li>سعی کنید از ویژگی ها موجود , تعدای ویژگی جدید ایجاد کنید یا آنها را ترکیب کنید.</li>
#     </font>
# </div>

# %%
# TODO: کتابخانه های مورد نیاز را ایمپورت کنید
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# TODO : متدی بتویسید که همبستگی چند جمله ایی را بررسی و مدیریت کند (Multicolinearity)
def remove_multicolinearity_features(dataframe, threshold=0.9):
  correlation_matrix=dataframe.corr()
  upper_triangle=correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
  to_drop=[column for column in upper_triangle.columns if any (upper_triangle[column]>threshold)]
  dataframe=dataframe.drop(columns=to_drop)
  return dataframe

def select_features_with_anova(dataframe, target_column, significance_level=0.05):
  significant_features=[]
  for feature in dataframe.columns:
    if feature!=target_column:
      formula=f"{target_column}~{feature}"
      model=ols(formula, data=dataframe). fit()
      annova_table=sm.stats.annova_lm(model,type=2)
      p_value=annova_table["PR(>F)"][0]
      if p_value<significant_level:
        significant_features.append(feature)
    return significant_features

# %%
# TODO : ویژگی هایی را به کمک روش Mutual Info انتخاب کنید.
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import SelectPercentile

numerics=['int16','int32','int64','float16','float32','float64']
numerical_features=list(df_copy.select_dtypes(include=numerics).columns)

data=df_copy[numerical_features]

X=data.drop(['CO(GT)'],axis=1)
y=data['CO(GT)']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)
X_train.shape,y_train.shape,X_test.shape,y_test.shape

mutual_info=mutual_info_regression(X_train.fillna(0),y_train)
mutual_info

mi_series=pd.Series(mutual_info)
mi_series.index=X_train.columns
mi_series.sort_values(ascending=False)

mi_series.sort_values(ascending=False).plot.bar(figsize=(20,8))

k_percentile_features=SelectPercentile(mutual_info_regression, percentile=10).fit(X_train.fillna(0),y_train)
k_percentile_features.fit(X_train.fillna(0),y_train)
X_train.columns[k_percentile_features.get_support()]
# Out:
# Index(['C6H6(GT)', 'PT08.S2(NMHC)'], dtype='object')

# %%
# ایجاد شاخص کلی آلودگی به عنوان متغیر جدید
import pandas as pd

df_copy["Pollution_Index"]= df_copy["C6H6(GT)"]+df_copy["NOx(GT)"]+df_copy["NO2(GT)"]

print(df_copy[["Pollution_Index"]])
# Out:
#       Pollution_Index
# 0               290.9
# 1               204.4
# 2               254.0
# 3               303.2
# 4               253.5
# ...               ...
# 9352            675.5
# 9353            543.4
# 9354            480.4
# 9355            400.5
# 9356            444.9
#
# [8693 rows x 1 columns]

# %%
# استانداردسازی داده‌ها
from sklearn.preprocessing import StandardScaler

features = ['CO(GT)','PT08.S2(NMHC)','C6H6(GT)','NOx(GT)','PT08.S1(CO)','PT08.S3(NOx)','PT08.S5(O3)','Pollution_Index']
df_copy = StandardScaler().fit_transform(df_copy[features])

df_copy=pd.DataFrame(df_copy,columns=['CO(GT)','PT08.S2(NMHC)','C6H6(GT)','NOx(GT)','PT08.S1(CO)','PT08.S3(NOx)','PT08.S5(O3)','Pollution_Index'])

# %% [markdown]
# <br>
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم پنجم: مدل‌سازی اولیه</strong>
#     </li>
# </font>
# <font size="4">
#     در این مرحله چند مدل را به‌صورت ساده آموزش می‌دهیم و در نهایت از بین آن‌ها ۱ الی ۲ مدل که بهترین عملکرد را دارند انتخاب می‌کنیم.
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>
#             <strong>ارزیابی اولیه عملکرد</strong> چند مدل پایه (به انتخاب شما) با معیارهای
#             <strong>MAE، MSE و R²</strong>.
#             <br>
#             در این مرحله چندین مدل مختلف را انتخاب کنید و آنها را روی داده‌های آموزشی و آزمایشی اجرا کنید. سپس عملکرد هر مدل را بر اساس معیارهای Mean Absolute Error (MAE)، Mean Squared Error (MSE) و ضریب تعیین (R²) بررسی کنید تا مشخص شود کدام مدل‌ها خطای کمتری دارند.
#         </li>
#         <br>
#         <li>
#             <strong>مقایسه تعمیم‌پذیری مدل‌ها</strong> با استفاده از نمودارهای
#             <strong>Learning Curve</strong>.
#             <br>
#             برای بررسی میزان تعمیم‌پذیری هر مدل، از نمودارهای Learning Curve استفاده کنید. این نمودار نشان می‌دهد که مدل شما چگونه با افزایش داده‌های آموزشی بهبود پیدا می‌کند و آیا دچار overfitting یا underfitting شده است. این تحلیل به شما کمک می‌کند تا مدل‌هایی را که عملکرد پایدارتری دارند شناسایی کنید.
#         </li>
#         <br>
#         <li>
#             <strong>شناسایی یک یا دو مدل برتر</strong> بر اساس کمترین خطای تست و بهترین تعمیم‌پذیری.
#             <br>
#             پس از ارزیابی مدل‌ها و مقایسه آنها با معیارهای ذکرشده، یک یا دو مدل که کمترین خطای تست را دارند و بهترین تعمیم‌پذیری را نشان می‌دهند انتخاب کنید. این مدل‌ها باید هم روی داده‌های آموزش و هم روی داده‌های آزمایش عملکرد مناسبی داشته باشند.
#         </li>
#         <br>
#         <li>
#             <strong>انتخاب مدل‌های مناسب</strong> برای بهینه‌سازی و تنظیم‌های بعدی بر اساس نتایج اولیه.
#             <br>
#             در نهایت، مدل‌هایی که در مراحل قبل عملکرد خوبی داشته‌اند را برای مرحله بهینه‌سازی انتخاب کنید. این مدل‌ها در مراحل بعدی با استفاده از روش‌هایی مانند تنظیم هایپرپارامترها (Hyperparameter Tuning) بهبود داده می‌شوند تا به بالاترین دقت ممکن برسند.
#         </li>
#         <br>
#         در ادامه منابعی برای مطالعه بیشتر در مورد منحنی یادگیری Learning Curve:
#     </font>
# </div>

# %% [markdown]
# [Learning Curves Tutorial](https://www.datacamp.com/tutorial/tutorial-learning-curves)

# %% [markdown]
# <div dir="rtl">
#     <font size=5 color="red">
#         اهداف اصلی:
#     </font>
#     <br>
#     <font size=4>
#         <li>
#             در نهایت مدل های اولیه را بررسی کنید و در قسمت ارزیابی بنویسید.
#         </li>
#         <li>
#             از Pipeline استفاده کنید و سعی کنید کد های خودتان را در قالب توابع بنویسید.
#         </li>
#         <li>
#             حتما منحنی یادگیری (Learning Curve) را برای هر مدل بررسی کنید.
#         </li>
#     </font>
# </div>
# <br>

# %%
# TODO : کتابخانه های مورد نیاز را ایمپورت کنید
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline

# %%
# TODO: چهار مدل اولیه را آموزش دهید و آنها را ارزیابی کنید
X=df_copy.drop('CO(GT)', axis="columns")
y=df_copy['CO(GT)']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

#تعریف تابع عمومی
def evaluate_model(model,X_train,X_test,y_train,y_test,is_poly=False,degree=2):
    if is_poly:
      poly = PolynomialFeatures(degree=degree)
      X_train = poly.fit_transform(X_train)
      X_test = poly.transform(X_test)
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    mse = mean_squared_error(y_test, predictions)
    r2 = r2_score(y_test, predictions)
    return mse, r2

# 4 مدل رگرسیونی
models = {
    "Polynomial Regression": Pipeline([
        ('poly_features', PolynomialFeatures(degree=2)),
        ('scaler', StandardScaler()),
        ('linear_regression', LinearRegression())
    ]),
    "Ridge Regression": Pipeline([
        ('scaler', StandardScaler()),
        ('ridge_regression', Ridge(alpha=1.0))
    ]),
    "Lasso Regression": Pipeline([
        ('scaler', StandardScaler()),
        ('lasso_regression', Lasso(alpha=0.1))
    ]),
    "Elastic Net": Pipeline([
        ('scaler', StandardScaler()),
        ('elastic_net', ElasticNet(alpha=0.1, l1_ratio=0.5))
    ])
}

# اجرای مدل‌ها و عملکرد آنها با پایپ لاین
results = []

for name, pipeline in models.items():
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    results.append({"Model": name, "MSE": mse, "R²": r2})

    results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                    Model       MSE        R²
# 0  Polynomial Regression  0.193897  0.810799
# 1       Ridge Regression  0.205512  0.799465
# 2       Lasso Regression  0.230659  0.774927
# 3            Elastic Net  0.225207  0.780247

# %%
# TODO : نمودار Learning Curve هر مدل را رسم کنید

from sklearn.model_selection import learning_curve

def plot_learning_curve(model, X, y, title, is_poly=False, degree=2):
    train_sizes, train_scores, test_scores = learning_curve (
        model, X, y, cv=5, scoring='neg_mean_squared_error', train_sizes=np.linspace(0.1, 1.0, 10)
                                                            )
    train_scores_mean = -np.mean(train_scores, axis=1)
    test_scores_mean = -np.mean(test_scores, axis=1)

    plt.figure()
    plt.title(title)
    plt.xlabel("Training Examples")
    plt.ylabel("Mean Squared Error")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training Score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-Validation Score")
    plt.legend(loc="best")
    plt.grid()
    plt.show()

# مدل‌ها
poly_model = make_pipeline(PolynomialFeatures(degree=2), LinearRegression())
ridge_model = Ridge(alpha=1.0)
lasso_model = Lasso(alpha=0.1)
elastic_model = ElasticNet(alpha=0.1, l1_ratio=0.5)

plot_learning_curve(poly_model, X, y, "Polynomial Regression Learning Curve", is_poly=True)
plot_learning_curve(ridge_model, X, y, "Ridge Regression Learning Curve")
plot_learning_curve(lasso_model, X, y, "Lasso Regression Learning Curve")
plot_learning_curve(elastic_model, X, y, "Elastic Net Learning Curve")

# %% [markdown]
# ### بررسی نمودار های یادگیری (Learning Curve)
# 1. منحنی های یادگیری رابطه بین عملکرد مدل و زمان را نشان می دهد.  در مدل اول مقدار میانگین مجذور خطا بالاست و از عدد بالای 5 به بالای صفر نزدیک شده است که کاهش قابل توجه آن در طول یادگیری خوب است.اما مقدار باز زیاد بوده و یادگیری با شیب بسیار ملایم در طول زمان بهتر شده است و فزاینده است با توجه به میزان ضریب تعیین این مدل بهترین مدل است.
# 2. در مدل دوم میزان میانگین مجذور خطا از عددی بالای 35 صدم به بالای 30 صدم کاهش داشته و میزان یادگیری به حدود 30 درصد رسیده است.

# %% [markdown]
# <br>
# <div dir="rtl">
# <font size="6">
#     <li>
#     <strong>قدم ششم: بهینه‌سازی مدل(های) منتخب</strong>
#     </li>
# </font>
# <font size="4">
#     در این مرحله مدل‌های برتر انتخاب‌شده را با استفاده از تنظیمات پیشرفته‌تر، بهینه‌سازی هایپرپارامترها و روش‌های بهبود عملکرد، دقیق‌تر آموزش می‌دهیم تا بهترین نتیجه را از داده‌ها استخراج کنیم.
# </font>
# </div>
# <br>

# %% [markdown]
# <div dir="rtl">
# <font size="4">
#     <li>پس فضای جستجوی پارامتر را تعریف کنید.</li>
#     <li>یکی از روش های GridSearch یا RandomSearch یا هر روش دیگه ایی که فکر می کنید مناسب بهینه سازی پارامتر ها است را پیاده سازی کنید.</li>
#     <li>سپس مدل بهینه شده را مجدد آموزش دهید.</li>
# </div>

# %%
# TODO: مدل منتخب در مرحله قبل را به کمک روش های بهینه سازی هایپر پارامتر بهبود دهید.

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import RandomizedSearchCV

# Pipeline
pipeline = Pipeline([
    ('poly_features', PolynomialFeatures()),
    ('scaler', StandardScaler()),
    ('linear_regression', LinearRegression())
])

param_distributions = {
    'poly_features__degree': np.arange(1, 5)
}

random_search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_distributions,
    n_iter=10,
    scoring='neg_mean_squared_error',
    cv=5,
    random_state=42
)

random_search.fit(X_train, y_train)

# بهترین پارامترها
best_degree = random_search.best_params_['poly_features__degree']
best_model = random_search.best_estimator_

y_pred = best_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Best Polynomial Degree:", best_degree)
print("MSE:", mse)
print("R²:", r2)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:317: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Polynomial Degree: 3
# MSE: 0.1812584650301148
# R²: 0.8231311733297095

# %%
# TODO: مدل بهینه شده را آموزش دهید.
poly = PolynomialFeatures(degree=4)
X_poly = poly.fit_transform(X_train)

poly_model = LinearRegression()
poly_model.fit(X_poly, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <div dir="rtl">
#     <font size=4>
#         <li>منحنی یادگیری را برای مدل بهینه شده را رسم کنید و این نمودار را در قسمت ارزیابی بررسی کنید.</li>
#     </font>
# </div>
# <br>

# %%
# TODO: نمودار منحنی یادگیری را برای مدل
plot_learning_curve(poly_model, X, y, "Polynomial Regression Learning Curve")

# %% [markdown]
# ### ارزیابی نهایی:
#
# **حتما در این بخش ارزیابی و نتیجه گیری نهایی از این تمرین اعم از پیش پردازش و مهندسی ویژگی و در نهایت کیفیت و عملکرد مدل یادگیری ماشین را بنویسید**
# 1. بصورت کلی مشاهده می شود که مراحل صورت گرفته امکان مشاهدهو بررسی  تاثیرات هوایی و را دارند و می توانند به درستی کار کنند هرچند که نیاز به اموزی بیشتر با دیتاهای دقیق تر و همچنین انالیز پذیر دارند
